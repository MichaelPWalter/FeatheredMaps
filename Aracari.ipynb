# %%
import pandas as pd

# Load the CSV file
file_path = 'C:\\Users\\Walter\\Documents\\GitHub\\FeatheredMaps\\Clements-v2024-October-2024-rev.csv'  # Replace with the path to your CSV file
df = pd.read_csv(file_path)

# Filter rows containing "aracari" or "Aracari"
filtered_df = df[df.apply(lambda row: row.astype(str).str.contains('aracari', case=False).any(), axis=1)]

# Save the filtered rows to a new CSV (optional)
filtered_df.to_csv('filtered_aracari.csv', index=False)

# Display the filtered rows
print(filtered_df)
# Out:
#       sort v2024 species_code Clements v2024b change text for website v2024b  \
# 9721     10774.0      greara1                    NaN                     NaN
# 9722     10775.0      letara1                    NaN                     NaN
# 9723     10776.0      letara2                    NaN                     NaN
# 9724     10777.0      letara3                    NaN                     NaN
# 9725     10778.0      colara1                    NaN                     NaN
# 9726     10779.0      colara2                    NaN                     NaN
# 9730     10783.0      colara4                    NaN                     NaN
# 9731     10784.0      colara5                    NaN                     NaN
# 9732     10785.0      fibara1                    NaN                     NaN
# 9733     10786.0      blnara1                    NaN                     NaN
# 9734     10787.0      bknara1                    NaN                     NaN
# ...
